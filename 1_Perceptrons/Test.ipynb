# %%
import os # Standard Library
import numpy as np
import pandas as pd

# %% [markdown]
# os -> Operating System management
# ---------------------------------
# 1. Folder Management
# 2. Folder Creation, remove
#
# Python Fundamental Data Types
# -----------------------------
# 1. List -> Mutable
# 2. Tuple -> Immutable
# 3. Set

# %%
# Out:
# ['Adaline.py',
#  'AdalineSGD.py',
#  'Analysis.py',
#  'Data',
#  'DataScraper.py',
#  'Perceptron.py',
#  'Results',
#  'Test.ipynb',
#  '__init__.py',
#  '__pycache__']

# %%
array = np.zeros(shape=(3, 2))
print(array)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
# One depth/folder below syntax
df1 = pd.read_csv("Data/Iris.csv", index_col=0)

# Root folder Syntax
df2 = pd.read_csv("Iris.csv", index_col=0)

# One depth/folder above syntax
df3 = pd.read_csv("../Iris.csv", index_col=0)

# %%
display(df1)
# Out:
#      Sepal_Length(cm)  Sepal_Width(cm)  Petal_Length(cm)  Petal_Width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#               Class
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
display(df2)
# Out:
#      Sepal_Length(cm)  Sepal_Width(cm)  Petal_Length(cm)  Petal_Width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#               Class
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
display(df3)
# Out:
#      Sepal_Length(cm)  Sepal_Width(cm)  Petal_Length(cm)  Petal_Width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#               Class
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
os.listdir()
# Out:
# ['Adaline.py',
#  'AdalineSGD.py',
#  'Analysis.py',
#  'Data',
#  'DataScraper.py',
#  'Iris.csv',
#  'Perceptron.py',
#  'Results',
#  'Test.ipynb',
#  '__init__.py',
#  '__pycache__']
